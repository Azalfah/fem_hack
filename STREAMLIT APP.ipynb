# %%
import streamlit as st
import pandas as pd
import joblib

st.title("🎓 Student Dropout Predictor")

model = joblib.load("model.joblib")

file = st.file_uploader("Upload CSV", type="csv")

if file:
    data = pd.read_csv(file)

    X = data.apply(pd.to_numeric, errors='coerce')
    X = X.fillna(0)

    probs = model.predict_proba(X)[:, 1]

    data['risk_score'] = probs
    data['risk_label'] = data['risk_score'].apply(
        lambda x: "High" if x>=0.7 else "Medium" if x>=0.4 else "Low"
    )

    st.dataframe(data)
# Out:
# 2026-01-31 16:28:40.156 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 16:28:40.449
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\HP\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-01-31 16:28:40.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 16:28:41.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 16:28:41.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 16:28:41.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 16:28:41.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 16:28:41.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
