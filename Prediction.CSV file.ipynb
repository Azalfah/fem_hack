# %%
import pandas as pd
import numpy as np

# %%
df=df=pd.read_csv('Student Record.zip')

# %%
submission = pd.DataFrame({
    'student_id': df.index,
})
submission.to_csv('predictions.csv', index=False)
submission.head()
# Out:
#    student_id
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
def risk_label(score):
    if score > 0.7: return "High"
    elif score > 0.4: return "Medium"
    else: return "Low"

# %%
submission.coulomns = ['Dropout_Probability', 'Risk_Category']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1304\606665825.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   submission.coulomns = ['Dropout_Probability', 'Risk_Category']

# %%
README (Short Report)
✔ Data Cleaning
Removed target leakage

Filled missing values with median

✔ Features Used
Academic performance

Enrollment history

Demographic indicators

✔ Model Choice
Logistic Regression

Transparent & explainable

✔ Risk Thresholds
Low < 0.4

Medium 0.4–0.7

High > 0.7

✔ Key Dropout Reasons
Low grades

High failures

Financial indicators
